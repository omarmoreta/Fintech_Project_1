# %%
from openbb_terminal.sdk import openbb
import quantstats as qs
import pandas as pd
qs.extend_pandas()

# %%
#load data from openBB
#stocks = ["QQQ", "DIA"]

data_spy = openbb.stocks.load("SPY", start_date="2013-02-08", end_date="2023-02-08")
data_cost = openbb.stocks.load("COST", start_date="2013-02-08", end_date="2023-02-08")
data_avgo = openbb.stocks.load("AVGO", start_date="2013-02-08", end_date="2023-02-08")
data_apd = openbb.stocks.load("APD", start_date="2013-02-08", end_date="2023-02-08")
data_amgn = openbb.stocks.load("AMGN", start_date="2013-02-08", end_date="2023-02-08")
data_cvx = openbb.stocks.load("CVX", start_date="2013-02-08", end_date="2023-02-08")
data_aapl = openbb.stocks.load("AAPL", start_date="2013-02-08", end_date="2023-02-08")
data_dis = openbb.stocks.load("DIS", start_date="2013-02-08", end_date="2023-02-08")
data_bac = openbb.stocks.load("BAC", start_date="2013-02-08", end_date="2023-02-08")
data_gs = openbb.stocks.load("GS", start_date="2013-02-08", end_date="2023-02-08")
data_sbux = openbb.stocks.load("SBUX", start_date="2013-02-08", end_date="2023-02-08")
data_cof = openbb.stocks.load("COF", start_date="2013-02-08", end_date="2023-02-08")
data_etn = openbb.stocks.load("ETN", start_date="2013-02-08", end_date="2023-02-08")
data_xom = openbb.stocks.load("XOM", start_date="2013-02-08", end_date="2023-02-08")
data_hd = openbb.stocks.load("HD", start_date="2013-02-08", end_date="2023-02-08")
data_ma = openbb.stocks.load("MA", start_date="2013-02-08", end_date="2023-02-08")
data_qqq = openbb.stocks.load("QQQ", start_date="2013-02-08", end_date="2023-02-08")
data_iwm = openbb.stocks.load("IWM", start_date="2013-02-08", end_date="2023-02-08")
data_jnj = openbb.stocks.load("JNJ", start_date="2013-02-08", end_date="2023-02-08")
data_jpm = openbb.stocks.load("JPM", start_date="2013-02-08", end_date="2023-02-08")
data_mcd = openbb.stocks.load("MCD", start_date="2013-02-08", end_date="2023-02-08")
data_mrk = openbb.stocks.load("MRK", start_date="2013-02-08", end_date="2023-02-08")
data_msft = openbb.stocks.load("MSFT", start_date="2013-02-08", end_date="2023-02-08")
data_nvda = openbb.stocks.load("NVDA", start_date="2013-02-08", end_date="2023-02-08")
data_nke = openbb.stocks.load("NKE", start_date="2013-02-08", end_date="2023-02-08")
data_pep = openbb.stocks.load("PEP", start_date="2013-02-08", end_date="2023-02-08")
data_pfe = openbb.stocks.load("PFE", start_date="2013-02-08", end_date="2023-02-08")
data_pg = openbb.stocks.load("PG", start_date="2013-02-08", end_date="2023-02-08")
data_mo = openbb.stocks.load("MO", start_date="2013-02-08", end_date="2023-02-08")
data_bud = openbb.stocks.load("BUD", start_date="2013-02-08", end_date="2023-02-08")
data_shw = openbb.stocks.load("SHW", start_date="2013-02-08", end_date="2023-02-08")
data_tsco = openbb.stocks.load("TSCO", start_date="2013-02-08", end_date="2023-02-08")
data_unh = openbb.stocks.load("UNH", start_date="2013-02-08", end_date="2023-02-08")
data_vz = openbb.stocks.load("VZ", start_date="2013-02-08", end_date="2023-02-08")
data_v = openbb.stocks.load("V", start_date="2013-02-08", end_date="2023-02-08")
data_wmt = openbb.stocks.load("WMT", start_date="2013-02-08", end_date="2023-02-08")
# Out:
# Loading Daily data for SPY with starting period 2013-02-08.
# Loading Daily data for COST with starting period 2013-02-08.
# Loading Daily data for AVGO with starting period 2013-02-08.
# Loading Daily data for APD with starting period 2013-02-08.
# Loading Daily data for AMGN with starting period 2013-02-08.
# Loading Daily data for CVX with starting period 2013-02-08.
# Loading Daily data for AAPL with starting period 2013-02-08.
# Loading Daily data for DIS with starting period 2013-02-08.
# Loading Daily data for BAC with starting period 2013-02-08.
# Loading Daily data for GS with starting period 2013-02-08.
# Loading Daily data for SBUX with starting period 2013-02-08.
# Loading Daily data for COF with starting period 2013-02-08.
# Loading Daily data for ETN with starting period 2013-02-08.
# Loading Daily data for XOM with starting period 2013-02-08.
# Loading Daily data for HD with starting period 2013-02-08.
# Loading Daily data for MA with starting period 2013-02-08.
# ...

# %%
#data check
data_msft.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# date
# 2023-02-01  248.000000  255.179993  245.470001  252.750000  252.750000
# 2023-02-02  258.820007  264.690002  257.250000  264.600006  264.600006
# 2023-02-03  259.540009  264.200012  257.100006  258.350006  258.350006
# 2023-02-06  257.440002  258.299988  254.779999  256.769989  256.769989
# 2023-02-07  260.529999  268.769989  260.079987  267.559998  267.559998
#
#               Volume
# date
# 2023-02-01  31259900
# 2023-02-02  39940400
# 2023-02-03  29062300
# 2023-02-06  22518000
# 2023-02-07  50841400

# %%
#use adjust close to calc daily returns
spy_returns = data_spy["Adj Close"].pct_change()
cost_returns = data_cost["Adj Close"].pct_change()
avgo_returns = data_avgo["Adj Close"].pct_change()
apd_returns = data_apd["Adj Close"].pct_change()
amgn_returns = data_amgn["Adj Close"].pct_change()
cvx_returns = data_cvx["Adj Close"].pct_change()
aapl_returns = data_aapl["Adj Close"].pct_change()
dis_returns = data_dis["Adj Close"].pct_change()
bac_returns = data_bac["Adj Close"].pct_change()
gs_returns = data_gs["Adj Close"].pct_change()
sbux_returns = data_sbux["Adj Close"].pct_change()
cof_returns = data_cof["Adj Close"].pct_change()
etn_returns = data_etn["Adj Close"].pct_change()
xom_returns = data_xom["Adj Close"].pct_change()
hd_returns = data_hd["Adj Close"].pct_change()
ma_returns = data_ma["Adj Close"].pct_change()
qqq_returns = data_qqq["Adj Close"].pct_change()
iwm_returns = data_iwm["Adj Close"].pct_change()
jnj_returns = data_jnj["Adj Close"].pct_change()
jpm_returns = data_jpm["Adj Close"].pct_change()
mcd_returns = data_mcd["Adj Close"].pct_change()
mrk_returns = data_mrk["Adj Close"].pct_change()
msft_returns = data_msft["Adj Close"].pct_change()
nvda_returns = data_nvda["Adj Close"].pct_change()
nke_returns = data_nke["Adj Close"].pct_change()
pep_returns = data_pep["Adj Close"].pct_change()
pfe_returns = data_pfe["Adj Close"].pct_change()
pg_returns = data_pg["Adj Close"].pct_change()
mo_returns = data_mo["Adj Close"].pct_change()
bud_returns = data_bud["Adj Close"].pct_change()
shw_returns = data_shw["Adj Close"].pct_change()
tsco_returns = data_tsco["Adj Close"].pct_change()
unh_returns = data_unh["Adj Close"].pct_change()
vz_returns = data_vz["Adj Close"].pct_change()
v_returns = data_v["Adj Close"].pct_change()
wmt_returns = data_wmt["Adj Close"].pct_change()

# %%
#weight the portfolio
portfolio = (
    (cost_returns* .0059) + (avgo_returns*.0088) + (apd_returns*.0066) + (amgn_returns*.0029) + (cvx_returns*.0191) + 
    (aapl_returns* .0125) + (dis_returns*.1366) + (bac_returns*.1109) + (gs_returns*.0044) + (sbux_returns*.0389) + 
    (cof_returns* .0132) + (etn_returns*.0264) + (xom_returns*.0345) + (hd_returns*.0066) + (ma_returns*.0125) +
    (qqq_returns* .0800) + (iwm_returns*.0352) + (jnj_returns*.0184) + (jpm_returns*.0228) + (mcd_returns*.0330) + 
    (mrk_returns* .0081) + (msft_returns*.0213) + (nvda_returns*.1043) + (nke_returns*.0264) + (pep_returns*.0110) + 
    (pfe_returns* .0404) + (pg_returns*.0125) + (mo_returns*.0162) + (bud_returns*.0360) + (shw_returns*.0073) + 
    (tsco_returns* .0492) + (unh_returns*.0066) + (vz_returns*.0235) + (v_returns*.0081) + (wmt_returns*.0132)
                )
portfolio.head()
# Out:
# date
# 2013-02-08         NaN
# 2013-02-11    0.002908
# 2013-02-12    0.003891
# 2013-02-13   -0.001182
# 2013-02-14    0.004757
# Name: Adj Close, dtype: float64

# %%
#metrics for the weighted portfolio vs spy(benchmark)
qs.reports.metrics(portfolio, spy_returns, mode="full")
# Out:
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2013-02-08  2013-02-08
# End Period                 2023-02-07  2023-02-07
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          483.51%     229.32%
# CAGR﹪                     19.28%      12.65%
#
# Sharpe                     1.01        0.77
# Prob. Sharpe Ratio         99.91%      99.18%
# Smart Sharpe               0.89        0.68
# Sortino                    1.43        1.07
# Smart Sortino              1.26        0.95
# Sortino/√2                 1.01        0.76
# Smart Sortino/√2           0.89        0.67
# Omega                      1.21        1.21
#
# Max Drawdown               -35.75%     -33.72%
# Longest DD Days            398         399
# Volatility (ann.)          19.45%      17.44%
# R^2                        0.93        0.93
# ...

# %%
#reports for weighted portfolio vs spy
qs.reports.plots(portfolio, spy_returns, mode="full", figsize=(15,10))
# Out:
# /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.9/site-packages/quantstats/stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
# /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.9/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
#qs.reports.html(portfolio, spy_returns)
# Out:
# /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.9/site-packages/quantstats/stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
# /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.9/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# ...
